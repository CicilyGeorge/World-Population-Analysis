# %%
import pandas as pd
import csv

# %%
file = "../data/populationDensity.csv"

# %%
birth_df = pd.read_csv(file, encoding="ISO-8859-1")

birth_df.head()
# Out:
#   ï»¿Country Name Country Code                        Indicator Name  \
# 0           Aruba          ABW  Death rate, crude (per 1,000 people)
# 1     Afghanistan          AFG  Death rate, crude (per 1,000 people)
# 2          Angola          AGO  Death rate, crude (per 1,000 people)
# 3         Albania          ALB  Death rate, crude (per 1,000 people)
# 4         Andorra          AND  Death rate, crude (per 1,000 people)
#
#    Indicator Code    1960    1961    1962    1963    1964    1965  ...  \
# 0  SP.DYN.CDRT.IN   6.388   6.241   6.118   6.012   5.920   5.839  ...
# 1  SP.DYN.CDRT.IN  32.219  31.649  31.093  30.551  30.022  29.501  ...
# 2  SP.DYN.CDRT.IN  27.097  26.859  26.627  26.407  26.194  25.966  ...
# 3  SP.DYN.CDRT.IN  11.326  10.719  10.175   9.707   9.320   9.009  ...
# 4  SP.DYN.CDRT.IN     NaN     NaN     NaN     NaN     NaN     NaN  ...
#
#      2011    2012   2013   2014   2015   2016   2017   2018  2019  2020
# ...

# %%
birth_df.describe()
# Out:
#              1960        1961        1962        1963        1964        1965  \
# count  239.000000  238.000000  239.000000  238.000000  238.000000  238.000000
# mean    16.375211   15.814925   15.449966   15.167561   14.865285   14.574650
# std      7.039185    6.868157    6.733386    6.644221    6.545176    6.434382
# min      5.700000    5.800000    5.800000    5.600000    5.300000    5.000000
# 25%     10.000000    9.775250    9.787446    9.691808    9.426681    9.410431
# 50%     15.676000   14.172000   12.932000   12.740500   12.295514   12.200000
# 75%     21.943000   20.455500   20.219500   19.847500   19.423000   19.006250
# max     36.838000   36.606000   36.335000   36.004000   35.604000   35.128000
#
#              1966        1967        1968        1969  ...        2011  \
# count  239.000000  238.000000  238.000000  238.000000  ...  251.000000
# mean    14.248368   14.020745   13.810935   13.606118  ...    7.952914
# ...
